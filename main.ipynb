# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "https://raw.githubusercontent.com/nogibjj/MiniProject2_LinHui_Falll2023/main/AAPL.csv"

# %%
df = pd.read_csv(path, index_col = 0)\
    .fillna(method = 'backfill')

print(df.head())
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-09-12  159.589996  164.259995  159.300003  163.429993  162.466171
# 2022-09-13  159.899994  160.539993  153.369995  153.839996  152.932739
# 2022-09-14  154.789993  157.100006  153.610001  155.309998  154.394073
# 2022-09-15  154.649994  155.240005  151.380005  152.369995  151.471390
# 2022-09-16  151.210007  151.350006  148.369995  150.699997  149.811249
#
#                Volume
# Date
# 2022-09-12  104956000
# 2022-09-13  122656600
# 2022-09-14   87965400
# 2022-09-15   90481100
# 2022-09-16  162278800

# %%
summary_stats = pd.concat([df.describe(include='all').drop('count').T, \
                           df.median().rename('median')], axis=1).T.round(decimals=2)
print(summary_stats)
# Out:
#           Open    High     Low   Close  Adj Close        Volume
# mean    160.47  162.26  158.89  160.65     160.19  6.948214e+07
# std      19.01   18.77   19.28   19.01      19.19  2.411895e+07
# min     126.01  127.77  124.17  125.02     124.49  3.145820e+07
# 25%     145.81  147.32  143.96  145.92     145.26  5.126040e+07
# 50%     154.93  157.44  153.42  155.32     154.70  6.462460e+07
# 75%     177.33  179.11  176.54  177.41     177.39  8.116722e+07
# max     196.24  198.23  195.28  196.45     196.19  1.647624e+08
# median  154.93  157.44  153.42  155.32     154.70  6.462460e+07

# %%
plt.plot(df['Open'])
plt.xticks(df.index[::40], rotation=20)
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open price for AAPL in the past year')
#plt.savefig('Open price figure.png')
plt.show()
